# %% [markdown]
# # Deployment Notebook
#
# ### OCR Invoice BYOP Model Deployment
#
# This notebook serves to deploy the OCR Invoice Model.
#
# In order to run this notebook, you must:
#
# 1. Update the `./private_key` folder with your Google service account key. Please rename it to `secret_key.json`.
# 2. Update the variables in the first code block to match your requirements.
#
# If you have any questions, please reach out to the Wallaroo Team!

# %%
# Update the private key folder
wallaroo_api_key = "OCR_data_engineer_creds.json"

# Wallaroo Variables
workspace_name = 'realpage-ocr'  # rename 
pipeline_name = 'ocr-mega'       # rename
model_name = 'mega-byop'         # rename
model_file_name = 'mega-byop.zip' # rename

# Location of the BYOP folder
folder_to_zip = 'ocr-mega-byop'

# %% [markdown]
# # Start Up Tasks
#
# These include
# - Imports
# - Connecting to the Wallaroo Client
# - Connecting to a workspace

# %%
# Needed Imports
import wallaroo
from wallaroo.deployment_config import DeploymentConfigBuilder
from wallaroo.framework import Framework

import pyarrow as pa
import numpy as np
import pandas as pd
import json
import os

import zipfile

pd.set_option('display.max_columns', None)

# %%
# Connecting to the Wallaro Client
wl = wallaroo.Client(request_timeout=600)
# Out:
# Please log into the following URL in a web browser:
#
# 	https://keycloak.wallaroo.realpage.com/auth/realms/master/device?user_code=WUAF-OOHW
#
# Login successful!

# %%
# Creating or connecting to a workspace
workspace = wl.get_workspace(name=workspace_name, create_if_not_exist=True)
wl.set_current_workspace(workspace)
# Out:
# {'name': 'realpage-ocr', 'id': 47, 'archived': False, 'created_by': 'eb5fb6dc-cb10-4f3d-a96e-2dcba5e0a10a', 'created_at': '2024-09-19T15:42:31.653268+00:00', 'models': [{'name': 'mega-byop', 'versions': 6, 'owner_id': '""', 'last_update_time': datetime.datetime(2024, 10, 2, 14, 9, 34, 580124, tzinfo=tzutc()), 'created_at': datetime.datetime(2024, 9, 19, 15, 45, 33, 647306, tzinfo=tzutc())}], 'pipelines': [{'name': 'ocr-mega', 'create_time': datetime.datetime(2024, 9, 19, 15, 54, 27, 301779, tzinfo=tzutc()), 'definition': '[]'}]}

# %% [markdown]
# # Mega OCR Deployment
# ## Input and Output Schema
#
# For this model, we will be sending it a list of buffered byte files. This occurs because PDFs are read as bytes, which we will then convert to uint8s.
#
# The output for this model is a list of strings. Each PDF will return a list of strings. The size of the list depends on the number of pages the PDF has, or the output of the model per page.

# %%
input_schema = pa.schema([
    pa.field("buffered_byte_files", pa.list_(pa.uint8()),nullable=False),
    pa.field("input_product_code", pa.string(),nullable=False),

])

output_schema = pa.schema([
    pa.field("generated_text", pa.list_(pa.string())),
])

# %% [markdown]
# # Packaging Up the BYOP Model
#
# This step takes in the raw BYOP files and zips them up to be uploaded to Wallaroo.

# %%
def zip_folder_contents(folder_path, zip_file_path):
    with zipfile.ZipFile(zip_file_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, start=folder_path)
                zipf.write(file_path, arcname)

zip_folder_contents(folder_to_zip, model_file_name)

with zipfile.ZipFile(model_file_name, 'r') as zipf:
    print(zipf.namelist())
# Out:
# ['ocr-mega.py', 'requirements.txt', '.ipynb_checkpoints/ocr-mega-checkpoint.py']

# %% [markdown]
# # Model Upload to Wallaroo
#
# Here we upload the zip file to Wallaroo.

# %%
model = wl.upload_model(model_name, 
    model_file_name,
    framework=Framework.CUSTOM,
    input_schema=input_schema,
    output_schema=output_schema,
)
model
# Out:
# Waiting for model loading - this will take up to 10.0min.
# Model is pending loading to a container runtime..
# Model is attempting loading to a container runtime........successful
#
# Ready
# {'name': 'mega-byop', 'version': '4cfb6519-d858-46fc-bc19-2580fdc05f4f', 'file_name': 'mega-byop.zip', 'image_path': 'proxy.replicated.com/proxy/wallaroo/ghcr.io/wallaroolabs/mac-deploy:v2024.1.0-5409', 'arch': 'x86', 'accel': 'none', 'last_update_time': datetime.datetime(2024, 10, 3, 20, 18, 1, 227625, tzinfo=tzutc())}

# %%
# to retrieve a model that has been uploaded.
# model = wl.get_model(name=model_name,version="dda4894f-064a-428b-aa38-096504d53c0a")
# model

# %% [markdown]
# # Defining the Deployment Config
#
# For this model, we have found this to be a successful configuration. This also uploads the secret key to be utilized with the BYOP model.

# %%
deployment_config = DeploymentConfigBuilder() \
    .cpus(1).memory('8Gi') \
    .sidekick_cpus(model, 2) \
    .sidekick_memory(model, '8Gi') \
    .sidekick_env(model, {"WALLAROO_CREDENTIALS": str(json.load(open(wallaroo_api_key, 'r')))}) \
    .build()

# %% [markdown]
# # Creating the Pipeline

# %%
# Find the pipeline, if no pipeline is found, build a new one.
try:
    pipeline = wl.get_pipeline(pipeline_name)
except:
    pipeline = wl.build_pipeline(pipeline_name)

print(pipeline)
# Out:
# {'name': 'ocr-mega', 'create_time': datetime.datetime(2024, 9, 19, 15, 54, 27, 301779, tzinfo=tzutc()), 'definition': '[]'}

# %% [markdown]
# # Deploy the Pipeline
#
# This will be used if you need to clean out the previous version of the pipeline.
#
# Sometimes the pipeline may not deploy within the standard amount of time. If you look at the status and see "pending," please keep refreshing the status using `pipeline.status()`.

# %%
pipeline.undeploy()
pipeline.clear()
pipeline.add_model_step(model)
pipeline.deploy(deployment_config=deployment_config)
# Out:
# Waiting for undeployment - this will take up to 600s .................................. ok
# Waiting for deployment - this will take up to 600s ........... ok
# {'name': 'ocr-mega', 'create_time': datetime.datetime(2024, 9, 19, 15, 54, 27, 301779, tzinfo=tzutc()), 'definition': "[{'ModelInference': {'models': [{'name': 'mega-byop', 'version': '4cfb6519-d858-46fc-bc19-2580fdc05f4f', 'sha': '0226c55f3842db621863fd473546eb23250bed76aedb42b580e24b1a2d458400'}]}}]"}

# %%
print(pipeline.status())
# Out:
# {'status': 'Running', 'details': [], 'engines': [{'ip': '10.140.16.9', 'name': 'engine-76bbf59bfb-nsqtr', 'status': 'Running', 'reason': None, 'details': [], 'pipeline_statuses': {'pipelines': [{'id': 'ocr-mega', 'status': 'Running', 'version': '9f38fe8a-de1f-430b-b622-35c027a9836e'}]}, 'model_statuses': {'models': [{'name': 'mega-byop', 'sha': '0226c55f3842db621863fd473546eb23250bed76aedb42b580e24b1a2d458400', 'status': 'Running', 'version': '4cfb6519-d858-46fc-bc19-2580fdc05f4f'}]}}], 'engine_lbs': [{'ip': '10.140.16.8', 'name': 'engine-lb-7b5d4689fd-wrxb9', 'status': 'Running', 'reason': None, 'details': []}], 'sidekicks': [{'ip': '10.140.26.15', 'name': 'engine-sidekick-mega-byop-129-867fb65978-p9brf', 'status': 'Running', 'reason': None, 'details': [], 'statuses': '\n'}]}

# %% [markdown]
# # Input Test Data
#
# Here there are two examples loaded into a batch input.
#
# We are using a two-page PDF and a one-page PDF. This is then packaged into the input dataframe used for inferencing.
#
# Steps to process data:
# - Read a PDF.
# - Convert the PDF bytes to uint8s.
# - Take the buffered input and insert it into the value of `buffered_byte_files`. This was the input schema we had defined earlier.

# %%
with open("sample_data/52807-combined.pdf", 'rb') as file:
    pdf_file_bytes = file.read()
    file.close()

with open("sample_data/k1.pdf",'rb') as file:
    pdf_file_bytes_1 = file.read()
    file.close()
    
with open("sample_data/hoa_budget.pdf",'rb') as file:
    pdf_file_bytes_2 = file.read()
    file.close()


buffered_input = np.frombuffer(pdf_file_bytes, dtype=np.uint8)
buffered_input_1 = np.frombuffer(pdf_file_bytes_1, dtype=np.uint8)
buffered_input_2 = np.frombuffer(pdf_file_bytes_2, dtype=np.uint8)


combined_df = pd.DataFrame({
        "input_product_code" : ["INV","K1","HOA"],
        "buffered_byte_files": [buffered_input.tolist(),buffered_input_1.tolist(),buffered_input_2.tolist()]
    })

# input_df = pd.DataFrame(
#     {
#         "input_product_code" : ["INV"],
#         "buffered_byte_files": [buffered_input.tolist()]
#     })

# %% [markdown]
# # Make an Inference

# %%
result = pipeline.infer(combined_df,timeout=600)
display(pd.DataFrame(result))
# Out:
#                      time                             in.buffered_byte_files  \
# 0 2024-10-03 20:19:22.391  [37, 80, 68, 70, 45, 49, 46, 54, 13, 37, 226, ...
# 1 2024-10-03 20:19:22.391  [37, 80, 68, 70, 45, 49, 46, 51, 10, 37, 196, ...
# 2 2024-10-03 20:19:22.391  [37, 80, 68, 70, 45, 49, 46, 51, 10, 37, 226, ...
#
#   in.input_product_code                                 out.generated_text  \
# 0                   INV  [{'INVOICE NUMBER': '52807', 'ACCOUNT NUMBER':...
# 1                    K1  [{'Schedule K-1 (Form 1065) 2021': {'Part I In...
# 2                   HOA  [              Category                       ...
#
#    anomaly.count
# 0              0
# 1              0
# 2              0

# %%
print(((result["out.generated_text"][0])))
# Out:
# ["{'INVOICE NUMBER': '52807', 'ACCOUNT NUMBER': 'LINCOLN PK', 'SALES #': None, 'DEPT. #': None, 'LOCATION': 'W', 'SOLD TO': 'RESIDENCES @ LINCOLN PK\\n1 MIDWAY PARK DR\\nN. DARTMOUTH\\n(508)-938-5139', 'SHIP TO': 'SRV LINCOLN PK', 'INVOICE DATE': datetime.date(2024, 1, 11), 'PO NUMBER': '157580', 'TERMS': 'NET DUE', 'PAY METHOD': 'ON ACCOUNT', 'SUB TOTAL': 389.88, 'TAX': '14.99', 'DELIVERY': None, 'DISCOUNT': None, 'TOTAL': 404.87, 'LineItems': [{'QTY': '1', 'MAKE': 'LAB', 'PRODUCT': 'SVC', 'DESCRIPTION': 'SERVICE & DIAGNOSTIC', 'PRICE': '150.00', 'EXTENSION': '150.00'}, {'QTY': '1', 'MAKE': 'WCI', 'PRODUCT': '316405000', 'DESCRIPTION': 'SEAL', 'PRICE': '136.98', 'EXTENSION': '136.98'}, {'QTY': '1', 'MAKE': 'WCI', 'PRODUCT': '316575500', 'DESCRIPTION': 'BEZEL', 'PRICE': '102.90', 'EXTENSION': '102.90'}], 'Notes': '*APT 207*\\nORDERED AND REPLACED SEAL AND BEZEL\\nALL OK NOW COMPLETE'}", "{'INVOICE': '63170', 'DATE': datetime.date(2024, 1, 13), 'ACCT': '33477', 'EMPLID': 'LXHOUTMA', 'Sold To:': 'MARION VILLAGE ESTATES\\n32 VILLAGE DRIVE\\nMARION MA\\n9024', 'QTY': '1', 'ITEM': '320023', 'DESCRIPTION': 'PUSH BUTTON 1.1 CU.FT BLACK', 'PRICE EA': 139.95, 'TOTAL': 148.7, 'SUBTOTAL': 139.95, 'Tax': '8.75', 'PAYMENTS': '148.70', 'BALANCE': '148.70', 'SIGNATURE:': None}"]

# %%
print(((result["out.generated_text"][1])))
# Out:
# ['{\'Schedule K-1 (Form 1065) 2021\': {\'Part I Information About the Partnership\': {"A Partnership\'s employer identification number": \'46-4097730\', "B Partnership\'s name, address, city, state, and ZIP code": \'ENVIVA PARTNERS, LP\\n7200 WISCONSIN AVENUE\\nSUITE 1000\\nBETHESDA, MD 20814\', \'C IRS Center where partnership filed return\': \'e-file\', \'D Check if this is a publicly traded partnership (PTP)\': \'BLANK\'}, \'Part II Information About the Partner\': {"E Partner\'s SSN or TIN (Do not use TIN of a disregarded entity. See instructions.)": \'----7730\', "F Partner\'s name, address, city, state, and ZIP code": \'SAMPLE K-1\\n10000 UNITS\\n7200 WISCONSIN AVENUE\\nSUITE 1000\\nBETHESDA, MD 20814\', \'G General partner or LLC member-manager\': \'BLANK\', \'Limited partner or other LLC member\': \'X\', \'H1 Domestic partner\': \'X\', \'Foreign partner\': \'BLANK\', "H2 If the partner is a disregarded entity (DE), enter the partner\'s": {\'TIN\': \'BLANK\', \'Name\': \'BLANK\'}, \'I1 What type of entity is this partner?\': \'Individual\', \'I2 If this partner is a retirement plan (IRA/SEP/Keogh/etc.), check here\': \'BLANK\'}, "J Partner\'s share of profit, loss, and capital": {\'Profit\': {\'Beginning\': \'0.038109 %\', \'Ending\': \'0.037766 %\'}, \'Loss\': {\'Beginning\': \'0.038109 %\', \'Ending\': \'0.037766 %\'}, \'Capital\': {\'Beginning\': \'0.038109 %\', \'Ending\': \'0.037766 %\'}}, "K Partner\'s share of liabilities": {\'Nonrecourse\': {\'Beginning\': \'$ BLANK\', \'Ending\': \'$ 132,216\'}, \'Qualified nonrecourse financing\': {\'Beginning\': \'BLANK\', \'Ending\': \'BLANK\'}, \'Recourse\': {\'Beginning\': \'BLANK\', \'Ending\': \'BLANK\'}}, "L Partner\'s capital account analysis": {\'Beginning capital account\': \'$ 271,500\', \'Capital contributed during the year\': \'$ BLANK\', \'Current year net income (loss)\': \'$ 0\', \'Other increase (decrease) (attach explanation)\': \'$ -38,816\', \'Withdrawals & distributions\': \'$ ( 25,100 )\', \'Ending capital account\': \'$ 207,584\'}, \'M Did the partner contribute property with a built-in gain or loss?\': \'X No\', "N Partner\'s Share of Net Unrecognized Section 704(c) Gain or (Loss)": {\'Beginning\': \'BLANK\', \'Ending\': \'BLANK\', \'Final K-1\': \'BLANK\', \'Amended K-1\': \'BLANK\'}, "Part III Partner\'s Share of Current Year Income, Deductions, Credits, and Other Items": {\'1 Ordinary business income (loss)\': \'-27,942\', \'2 Net rental real estate income (loss)\': \'BLANK\', \'3 Other net rental income (loss)\': \'BLANK\', \'4a Guaranteed payments for services\': \'BLANK\', \'4b Guaranteed payments for capital\': \'BLANK\', \'4c Total guaranteed payments\': \'BLANK\', \'5 Interest income\': \'BLANK\', \'6a Ordinary dividends\': \'0\', \'6b Qualified dividends\': \'BLANK\', \'6c Dividend equivalents\': \'BLANK\', \'7 Royalties\': \'BLANK\', \'8 Net short-term capital gain (loss)\': \'BLANK\', \'9a Net long-term capital gain (loss)\': \'0\', \'9b Collectibles (28%) gain (loss)\': \'BLANK\', \'9c Unrecaptured section 1250 gain\': \'BLANK\', \'10 Net section 1231 gain (loss)\': \'BLANK\', \'11 Other income (loss)\': \'BLANK\', \'12 Section 179 deduction\': \'BLANK\', \'13 Other deductions\': {\'V\': \'-27,942\', \'W\': \'BLANK\'}, \'14 Self-employment earnings (loss)\': \'216,999\', \'15 Credits\': \'BLANK\', \'16 Schedule K-3 is attached if checked\': \'BLANK\', \'17 Alternative minimum tax (AMT) items\': \'1,681\', \'18 Tax-exempt income and nondeductible expenses\': \'100\', \'19 Distributions\': \'25,100\', \'20 Other information\': {\'A\': \'0\', \'N\': \'BLANK\', \'U\': \'BLANK\', \'V\': \'-27,942\', \'W\': \'BLANK\', \'Z\': \'BLANK\', \'AA\': \'-27,942\', \'AG\': \'BLANK\'}, \'21 Foreign taxes paid or accrued\': \'BLANK\', \'22 More than one activity for at-risk purposes*\': \'BLANK\', \'23 More than one activity for passive activity purposes*\': \'BLANK\'}}}']

# %%
print(((result["out.generated_text"][2])))
# Out:
# ['              Category                         Account Month    Amount\n0               INCOME             3000 Homeowner Fees   Jan  21082.26\n1               INCOME             3000 Homeowner Fees   Feb  21082.26\n2               INCOME             3000 Homeowner Fees   Mar  21082.26\n3               INCOME             3000 Homeowner Fees   Apr  21082.26\n4               INCOME             3000 Homeowner Fees   May  21082.26\n5               INCOME             3000 Homeowner Fees   Jun  21082.26\n6               INCOME             3000 Homeowner Fees   Jul  21082.26\n7               INCOME             3000 Homeowner Fees   Aug  21082.26\n8               INCOME             3000 Homeowner Fees   Sep  21082.26\n9               INCOME             3000 Homeowner Fees   Oct  21082.26\n10              INCOME             3000 Homeowner Fees   Nov  21082.26\n11              INCOME             3000 Homeowner Fees   Dec  21082.30\n12             EXPENSE                  4010 Insurance   Jan   1685.89\n13             EXPENSE                  4010 Insurance   Feb   1685.89\n14             EXPENSE                  4010 Insurance   Mar   1685.89\n15             EXPENSE                  4010 Insurance   Apr   1685.89\n16             EXPENSE                  4010 Insurance   May   1685.89\n17             EXPENSE                  4010 Insurance   Jun   1685.89\n18             EXPENSE                  4010 Insurance   Jul   1685.89\n19             EXPENSE                  4010 Insurance   Aug   1685.89\n20             EXPENSE                  4010 Insurance   Sep   1685.89\n21             EXPENSE                  4010 Insurance   Oct   1685.89\n22             EXPENSE                  4010 Insurance   Nov   1685.89\n23             EXPENSE                  4010 Insurance   Dec   1685.85\n24             EXPENSE         4020 Management Expense   Jan   2191.67\n25             EXPENSE         4020 Management Expense   Feb   2191.67\n26             EXPENSE         4020 Management Expense   Mar   2191.67\n27             EXPENSE         4020 Management Expense   Apr   2191.67\n28             EXPENSE         4020 Management Expense   May   2191.67\n29             EXPENSE         4020 Management Expense   Jun   2191.67\n30             EXPENSE         4020 Management Expense   Jul   2191.67\n31             EXPENSE         4020 Management Expense   Aug   2191.67\n32             EXPENSE         4020 Management Expense   Sep   2191.67\n33             EXPENSE         4020 Management Expense   Oct   2191.67\n34             EXPENSE         4020 Management Expense   Nov   2191.67\n35             EXPENSE         4020 Management Expense   Dec   2191.63\n36             EXPENSE                 4030 Legal Fees   Jan     83.33\n37             EXPENSE                 4030 Legal Fees   Feb     83.33\n38             EXPENSE                 4030 Legal Fees   Mar     83.33\n39             EXPENSE                 4030 Legal Fees   Apr     83.33\n40             EXPENSE                 4030 Legal Fees   May     83.33\n41             EXPENSE                 4030 Legal Fees   Jun     83.33\n42             EXPENSE                 4030 Legal Fees   Jul     83.33\n43             EXPENSE                 4030 Legal Fees   Aug     83.33\n44             EXPENSE                 4030 Legal Fees   Sep     83.33\n45             EXPENSE                 4030 Legal Fees   Oct     83.33\n46             EXPENSE                 4030 Legal Fees   Nov     83.33\n47             EXPENSE                 4030 Legal Fees   Dec     83.37\n48             EXPENSE         4040 Office & Admin-CMA   Jan    133.33\n49             EXPENSE         4040 Office & Admin-CMA   Feb    133.33\n50             EXPENSE         4040 Office & Admin-CMA   Mar    133.33\n51             EXPENSE         4040 Office & Admin-CMA   Apr    133.33\n52             EXPENSE         4040 Office & Admin-CMA   May    133.33\n53             EXPENSE         4040 Office & Admin-CMA   Jun    133.33\n54             EXPENSE         4040 Of ...

# %%
import ast
import re
import pandas as pd

# Function to replace datetime.date with date strings
def replace_datetime_date(s):
    pattern = r'datetime\.date\((\d+), (\d+), (\d+)\)'
    def repl(match):
        year, month, day = match.groups()
        return f"'{year}-{month.zfill(2)}-{day.zfill(2)}'"
    return re.sub(pattern, repl, s)

# Process the data
processed_data = [replace_datetime_date(s) for s in result["out.generated_text"][0]]

# Parse the strings into dictionaries
parsed_data = [ast.literal_eval(s) for s in processed_data]

# List to hold combined invoice and line item data
combined_data = []

for invoice in parsed_data:
    # Copy invoice data
    invoice_data = invoice.copy()
    # Determine line items key
    if 'line_items' in invoice_data:
        line_items_key = 'line_items'
    elif 'ITEM' in invoice_data:
        line_items_key = 'ITEM'
    else:
        line_items_key = None
    # Extract line items
    if line_items_key:
        line_items = invoice_data.pop(line_items_key)
        # For each line item, combine with invoice data
        for item in line_items:
            combined_row = invoice_data.copy()
            combined_row.update(item)
            combined_data.append(combined_row)
    else:
        # No line items, just add the invoice data
        combined_data.append(invoice_data)

# Create DataFrame
df = pd.DataFrame(combined_data)

df
# Out:
#   invoice_number invoice_date account_number                          vendor  \
# 0          52807   2024-01-11     LINCOLN PK  APPLIANCE CARE SERVICE COMPANY
# 1          52807   2024-01-11     LINCOLN PK  APPLIANCE CARE SERVICE COMPANY
# 2          52807   2024-01-11     LINCOLN PK  APPLIANCE CARE SERVICE COMPANY
# 3            NaN          NaN            NaN                             NaN
#
#                             vendor_address  vendor_phone  \
# 0  1261 GLOBE STREET\nFALL RIVER, MA 02721  508-674-0361
# 1  1261 GLOBE STREET\nFALL RIVER, MA 02721  508-674-0361
# 2  1261 GLOBE STREET\nFALL RIVER, MA 02721  508-674-0361
# 3                                      NaN           NaN
#
#              customer_name                         customer_address  \
# 0  RESIDENCES @ LINCOLN PK  1 MIDWAY PARK DR\nN.DARTMOUTH\nMA 02747
# 1  RESIDENCES @ LINCOLN PK  1 MIDWAY PARK DR\nN.DARTMOUTH\nMA 02747
# 2  RESIDENCES @ LINCOLN PK  1 MIDWAY PARK DR\nN.DARTMOUTH\nMA 02747
# 3                      NaN                                      NaN
#
#    customer_phone         ship_to ship_to_id po_number    terms  pay_method  \
# 0  (508)-938-5139  SRV LINCOLN PK     157580    157580  NET DUE  ON ACCOUNT
# 1  (508)-938-5139  SRV LINCOLN PK     157580    157580  NET DUE  ON ACCOUNT
# 2  (508)-938-5139  SRV LINCOLN PK     157580    157580  NET DUE  ON ACCOUNT
# 3             NaN             NaN        NaN       NaN      NaN         NaN
#
#    subtotal    tax  delivery  discount   total  \
# 0    389.88  14.99       NaN       NaN  404.87
# 1    389.88  14.99       NaN       NaN  404.87
# 2    389.88  14.99       NaN       NaN  404.87
# 3       NaN    NaN       NaN       NaN     NaN
#
#                                                notes  qty make    product  \
# 0  *APT 207*\nORDERED AND REPLACED SEAL AND BEZEL...    1  LAB        SVC
# 1  *APT 207*\nORDERED AND REPLACED SEAL AND BEZEL...    1  WCI  316405000
# 2  *APT 207*\nORDERED AND REPLACED SEAL AND BEZEL...    1  WCI  316575500
# 3                                                NaN  NaN  NaN        NaN
#
#             description   price extension INVOICE        DATE   ACCT  \
# 0  SERVICE & DIAGNOSTIC  150.00    150.00     NaN         NaN    NaN
# 1                  SEAL  136.98    136.98     NaN         NaN    NaN
# 2                 BEZEL  102.90    102.90     NaN         NaN    NaN
# 3                   NaN     NaN       NaN   63170  2024-01-13  33477
#
#      EMPLID                                           Sold To:  SUBTOTAL  \
# 0       NaN                                                NaN       NaN
# 1       NaN                                                NaN       NaN
# 2       NaN                                                NaN       NaN
# 3  LXHOUTMA  MARION VILLAGE ESTATES\n32 VILLAGE DRIVE\nMARI...    139.95
#
#     Tax   TOTAL PAYMENTS BALANCE  QTY    ITEM                  DESCRIPTION  \
# 0   NaN     NaN      NaN     NaN  NaN     NaN                          NaN
# 1   NaN     NaN      NaN     NaN  NaN     NaN                          NaN
# 2   NaN     NaN      NaN     NaN  NaN     NaN                          NaN
# 3  8.75  139.95   148.70  148.70    1  320023  PUSH BUTTON 1.1 CU.FT BLACK
#
#   PRICE EA
# 0      NaN
# 1      NaN
# 2      NaN
# 3   139.95

# %%
import ast
import pandas as pd

# Parse the string into a dictionary
parsed_data = [ast.literal_eval(entry) for entry in result["out.generated_text"][1]]

# Function to flatten nested dictionaries
def flatten_dict(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# Flatten the data
flattened_data = []
for entry in parsed_data:
    for key, value in entry.items():
        flattened_entry = flatten_dict(value)
        flattened_entry['Form'] = key
        flattened_data.append(flattened_entry)

# Create DataFrame
k1_df = pd.DataFrame(flattened_data)

k1_df
# Out:
#   Part I Information About the Partnership_A Partnership's employer identification number  \
# 0                                         46-4097730
#
#   Part I Information About the Partnership_B Partnership's name, address, city, state, and ZIP code  \
# 0  ENVIVA PARTNERS, LP\n7200 WISCONSIN AVENUE\nSU...
#
#   Part I Information About the Partnership_C IRS Center where partnership filed return  \
# 0                                             e-file
#
#   Part I Information About the Partnership_D Check if this is a publicly traded partnership (PTP)  \
# 0                                              BLANK
#
#   Part II Information About the Partner_E Partner's SSN or TIN (Do not use TIN of a disregarded entity. See instructions.)  \
# 0                                           ----7730
#
#   Part II Information About the Partner_F Partner's name, address, city, state, and ZIP code  \
# 0  SAMPLE K-1\n10000 UNITS\n7200 WISCONSIN AVENUE...
#
#   Part II Information About the Partner_G General partner or LLC member-manager  \
# 0                                              BLANK
#
#   Part II Information About the Partner_Limited partner or other LLC member  \
# 0                                                  X
#
#   Part II Information About the Partner_H1 Domestic partner  \
# 0                                                  X
#
#   Part II Information About the Partner_Foreign partner  \
# 0                                              BLANK
#
#   Part II Information About the Partner_H2 If the partner is a disregarded entity (DE), enter the partner's_TIN  \
# 0                                              BLANK
#
#   Part II Information About the Partner_H2 If the partner is a disregarded entity (DE), enter the partner's_Name  \
# 0                                              BLANK
#
#   Part II Information About the Partner_I1 What type of entity is this partner?  \
# 0                                         Individual
#
#   Part II Information About the Partner_I2 If this partner is a retirement plan (IRA/SEP/Keogh/etc.), check here  \
# 0                                              BLANK
#
#   J Partner's share of profit, loss, and capital_Profit_Beginning  \
# 0                                         0.038109 %
#
#   J Partner's share of profit, loss, and capital_Profit_Ending  \
# 0                                         0.037766 %
#
#   J Partner's share of profit, loss, and capital_Loss_Beginning  \
# 0                                         0.038109 %
#
#   J Partner's share of profit, loss, and capital_Loss_Ending  \
# 0                                         0.037766 %
#
#   J Partner's share of profit, loss, and capital_Capital_Beginning  \
# 0                                         0.038109 %
#
#   J Partner's share of profit, loss, and capital_Capital_Ending  \
# 0                                         0.037766 %
#
#   K Partner's share of liabilities_Nonrecourse_Beginning  \
# 0                                            $ BLANK
#
#   K Partner's share of liabilities_Nonrecourse_Ending  \
# 0                                          $ 132,216
#
#   K Partner's share of liabilities_Qualified nonrecourse financing_Beginning  \
# 0                                              BLANK
#
#   K Partner's share of liabilities_Qualified nonrecourse financing_Ending  \
# 0                                              BLANK
#
#   K Partner's share of liabilities_Recourse_Beginning  \
# 0                                              BLANK
#
#   K Partner's share of liabilities_Recourse_Ending  \
# 0                                            BLANK
#
#   L Partner's capital account analysis_Beginning capital account  \
# 0                                            271,500
#
#   L Partner's capital account analysis_Capital contributed during the year  \
# 0                                              BLANK
#
#   L Partner's capital account analysis_Current year net income (loss)  \
# 0                                                  0
#
#   L Partner's capital account analysis_Other increase (decrease) (attach explanation)  \
# 0                                            -38,816
#
#   L Partner's capital account analysis_Withdrawals & distributions  \
# 0                                         ( 25,100 )
#
#   L Partner's capital account analysis_Ending capital account  \
# 0                                            207,584
#
#   M Did the partner contribute property with a built-in gain or loss?  \
# 0                                               X No
#
#   N Partner's Share of Net Unrecognized Section 704(c) Gain or (Loss)_Beginning  \
# 0                                              BLANK
#
#   N Partner's Share of Net Unrecognized Section 704(c) Gain or (Loss)_Ending  \
# 0                                              BLANK
#
#   N Partner's Share of Net Unrecognized Section 704(c) Gain or (Loss)_Final K-1  \
# 0                                              BLANK
#
#   N Partner's Share of Net Unrecognized Section 704(c) Gain or (Loss)_Amended K-1  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_1 Ordinary business income (loss)  \
# 0                                            -27,942
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_2 Net rental real estate income (loss)  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_3 Other net rental income (loss)  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_4a Guaranteed payments for services  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_4b Guaranteed payments for capital  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_4c Total guaranteed payments  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_5 Interest income  \
# 0                                               0 L*
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_6a Ordinary dividends  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_6b Qualified dividends  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_6c Dividend equivalents  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_7 Royalties  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_8 Net short-term capital gain (loss)  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_9a Net long-term capital gain (loss)  \
# 0                                                  0
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_9b Collectibles (28%) gain (loss)  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_9c Unrecaptured section 1250 gain  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_10 Net section 1231 gain (loss)  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_11 Other income (loss)  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_12 Section 179 deduction  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_13 Other deductions_V  \
# 0                                            -27,942
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_13 Other deductions_W  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_14 Self-employment earnings (loss)  \
# 0                                            216,999
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_15 Credits  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_16 Schedule K-3 is attached if checked  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_17 Alternative minimum tax (AMT) items  \
# 0                                              1,681
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_18 Tax-exempt income and nondeductible expenses  \
# 0                                                100
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_19 Distributions  \
# 0                                             25,100
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_20 Other information_A  \
# 0                                                  0
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_20 Other information_N  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_20 Other information_U  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_20 Other information_V  \
# 0                                            -27,942
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_20 Other information_W  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_20 Other information_Z  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_20 Other information_AA  \
# 0                                            -27,942
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_20 Other information_AG  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_21 Foreign taxes paid or accrued  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_22 More than one activity for at-risk purposes*  \
# 0                                              BLANK
#
#   Part III Partner's Share of Current Year Income, Deductions, Credits, and Other Items_23 More than one activity for passive activity purposes*  \
# 0                                              BLANK
#
#                             Form
# 0  Schedule K-1 (Form 1065) 2021

# %% [markdown]
# ## Next Step: Utilize the API
